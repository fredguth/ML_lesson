# %%
import torch
import fastai
from fastai import *
from fastai.vision import *
import numpy as np
import matplotlib.pyplot as plt

# %%
fastai.__version__
# Out:
# '1.0.25.dev0'

# %%
torch.manual_seed(17);
use_gpu = torch.cuda.is_available();use_gpu
# Out:
# True

# %%
path = untar_data(URLs.MNIST)
def flat768(x):
    print (x.view(-1,768))

# %%
tfms=tfms+[flat768]

# %%
data = ImageDataBunch.from_folder(path, train='training', valid='testing', ds_tfms=tfms, size=28)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-47-59a82c14e5fd> in <module>()
# ----> 1 data = ImageDataBunch.from_folder(path, train='training', valid='testing', ds_tfms=tfms, size=28)
#
# ~/Code/fastai/fastai/vision/data.py in from_folder(cls, path, train, valid, valid_pct, classes, **kwargs)
#     115         else: src = il.random_split_by_pct(valid_pct)
#     116         src = src.label_from_folder(classes=classes)
# --> 117         return cls.create_from_ll(src, **kwargs)
#     118
#     119     @classmethod
#
# ~/Code/fastai/fastai/vision/data.py in create_from_ll(cls, dss, bs, ds_tfms, num_workers, tfms, device, test, collate_fn, size, **kwargs)
#     102                 num_workers:int=defaults.cpus, tfms:Optional[Collection[Callable]]=None, device:torch.device=None,
#     103                 test:Optional[PathOrStr]=None, collate_fn:Callable=data_collate, size:int=None, **kwargs)->'ImageDataBunch':
# --> 104         dss = dss.transform(tfms=ds_tfms, size=size, **kwargs)
#     105         if test is not None: dss.add_test_folder(test)
#     106         return dss.databunch(bs=bs, tfms=tfms, num_workers=num_workers, collate_fn=collate_fn, device=device)
#
# ~/Code/fastai/fastai/data_block.py in transform(self, tfms, **kwargs)
#     280         if not tfms: return self
#     281         self.train.transform(tfms[0], **kwargs)
# --> 282         self.valid.transform(tfms[1], **kwargs)
#     283         if self.test: self.test.transform(tfms[1], **kwargs)
#     284         return self
#
# IndexError: list index out of range

# %%
data.normalize()
data.show_batch()

# %%
import torch.nn as nn

# %%
data.tfms = [flat768]

# %%
net = nn.Sequential(
    nn.Linear(28*28, 16),
    nn.ReLU(),
    nn.Linear(16, 16),
    nn.ReLU(),
    nn.Linear(16, 10),
    nn.LogSoftmax()
).cuda()

# %%
loss_function=nn.NLLLoss()
metrics=[accuracy]
opt=optim.SGD(net.parameters(), lr=1e-1)

# %%
fit(model=net, data=data, epochs=5, loss_func=loss_function, opt=opt, metrics=metrics)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, max=5), HTML(value='0.00% [0/5 00:00<00:00]'))), HTML(value…
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-44-3708334a413f> in <module>()
# ----> 1 fit(model=net, data=data, epochs=5, loss_func=loss_function, opt=opt, metrics=metrics)
#
# ~/Code/fastai/fastai/basic_train.py in fit(epochs, model, loss_func, opt, data, callbacks, metrics)
#      92     except Exception as e:
#      93         exception = e
# ---> 94         raise e
#      95     finally: cb_handler.on_train_end(exception)
#      96
#
# ~/Code/fastai/fastai/basic_train.py in fit(epochs, model, loss_func, opt, data, callbacks, metrics)
#      82             for xb,yb in progress_bar(data.train_dl, parent=pbar):
#      83                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# ---> 84                 loss = loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      85                 if cb_handler.on_batch_end(loss): break
#      86
#
# ~/Code/fastai/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      16     if not is_listy(xb): xb = [xb]
#      17     if not is_listy(yb): yb = [yb]
# ---> 18     out = model(*xb)
#      19     out = cb_handler.on_loss_begin(out)
#      20
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     477             result = self._slow_forward(*input, **kwargs)
#     478         else:
# --> 479             result = self.forward(*input, **kwargs)
#     480         for hook in self._forward_hooks.values():
#     481             hook_result = hook(self, input, result)
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     477             result = self._slow_forward(*input, **kwargs)
#     478         else:
# --> 479             result = self.forward(*input, **kwargs)
#     480         for hook in self._forward_hooks.values():
#     481             hook_result = hook(self, input, result)
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      61
#      62     def forward(self, input):
# ---> 63         return F.linear(input, self.weight, self.bias)
#      64
#      65     def extra_repr(self):
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1200         return torch.addmm(bias, input, weight.t())
#    1201
# -> 1202     output = input.matmul(weight.t())
#    1203     if bias is not None:
#    1204         output += bias
#
# RuntimeError: size mismatch, m1: [5376 x 28], m2: [784 x 16] at /opt/conda/conda-bld/pytorch-nightly_1541668486622/work/aten/src/THC/generic/THCTensorMathBlas.cu:266

# %%
784*16
# Out:
# 12544

# %%
2352/768
# Out:
# 3.0625
